# %%
import tensorflow as tf
from tensorflow.contrib.learn.python.learn.datasets import mnist
from tensorflow.contrib.learn.python.learn.metric_spec import MetricSpec

# %%
learn = tf.contrib.learn
slim = tf.contrib.slim

# %%
def cnn(x, y):
    x = tf.reshape(x, [-1, 28, 28, 1])
    y = slim.one_hot_encoding(y, 10)

    net = slim.conv2d(x, 48, [5,5], scope='conv1')
    net = slim.max_pool2d(net, [2,2], scope='pool1')
    net = slim.conv2d(net, 96, [5,5], scope='conv2')
    net = slim.max_pool2d(net, [2,2], scope='pool2')
    net = slim.flatten(net, scope='flatten')
    net = slim.fully_connected(net, 512, scope='fully_connected1')
    logits = slim.fully_connected(net, 10,
            activation_fn=None, scope='fully_connected2')

    prob = slim.softmax(logits)
    loss = slim.losses.softmax_cross_entropy(logits, y)

    train_op = slim.optimize_loss(loss, slim.get_global_step(),
            learning_rate=0.001,
            optimizer='Adam')

    return {'class': tf.argmax(prob, 1), 'prob': prob},\
            loss, train_op

# %%
data_sets = mnist.read_data_sets('/tmp/mnist', one_hot=False)

train_X = data_sets.train.images
train_Y = data_sets.train.labels

test_X = data_sets.validation.images
test_Y = data_sets.validation.labels
# Out:
# Extracting /tmp/mnist/train-images-idx3-ubyte.gz
# Extracting /tmp/mnist/train-labels-idx1-ubyte.gz
# Extracting /tmp/mnist/t10k-images-idx3-ubyte.gz
# Extracting /tmp/mnist/t10k-labels-idx1-ubyte.gz

# %%
tf.logging.set_verbosity(tf.logging.INFO)
validation_metrics = {
    "accuracy" : MetricSpec(
        metric_fn=tf.contrib.metrics.streaming_accuracy,
        prediction_key="class")
}
validation_monitor = learn.monitors.ValidationMonitor(
        test_X,
        test_Y,
        metrics=validation_metrics,
        every_n_steps=100)
# Out:
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:267: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.

# %%
classifier = learn.Estimator(model_fn=cnn, model_dir='/tmp/cnn_log',
    config=learn.RunConfig(save_checkpoints_secs=10))
classifier.fit(x=train_X, y=train_Y, steps=3200, batch_size=64,
    monitors=[validation_monitor])
# Out:
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1297975c0>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 10, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': None}
# WARNING:tensorflow:From <ipython-input-15-8d9d3b3ba464>:4: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-15-8d9d3b3ba464>:4: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-15-8d9d3b3ba464>:4: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with batch_size is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:loss = 2.29386, step = 1
# INFO:tensorflow:Saving checkpoints for 32 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 62 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 95 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:32:54
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-95
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:33:04
# INFO:tensorflow:Saving dict for global step 95: accuracy = 0.9584, global_step = 95, loss = 0.144165
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 100): accuracy = 0.9584, loss = 0.144165, global_step = 95
# INFO:tensorflow:Saving checkpoints for 101 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.24083
# INFO:tensorflow:loss = 0.175144, step = 101 (44.628 sec)
# INFO:tensorflow:Saving checkpoints for 131 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 160 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 191 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:33:40
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-191
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:33:50
# INFO:tensorflow:Saving dict for global step 191: accuracy = 0.9754, global_step = 191, loss = 0.0828019
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 200): accuracy = 0.9754, loss = 0.0828019, global_step = 191
# INFO:tensorflow:Saving checkpoints for 201 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.24101
# INFO:tensorflow:loss = 0.125167, step = 201 (44.623 sec)
# INFO:tensorflow:Saving checkpoints for 230 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 259 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 286 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:34:27
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-286
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:34:37
# INFO:tensorflow:Saving dict for global step 286: accuracy = 0.9778, global_step = 286, loss = 0.0680794
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 300): accuracy = 0.9778, loss = 0.0680794, global_step = 286
# INFO:tensorflow:Saving checkpoints for 301 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.11898
# INFO:tensorflow:loss = 0.0460228, step = 301 (47.192 sec)
# INFO:tensorflow:Saving checkpoints for 330 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 360 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 390 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:35:12
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-390
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:35:21
# INFO:tensorflow:Saving dict for global step 390: accuracy = 0.9802, global_step = 390, loss = 0.0692536
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 400): accuracy = 0.9802, loss = 0.0692536, global_step = 390
# INFO:tensorflow:Saving checkpoints for 401 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.28119
# INFO:tensorflow:loss = 0.0157421, step = 401 (43.837 sec)
# INFO:tensorflow:Saving checkpoints for 430 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 460 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 491 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:35:56
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-491
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:36:04
# INFO:tensorflow:Saving dict for global step 491: accuracy = 0.985, global_step = 491, loss = 0.0554268
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 500): accuracy = 0.985, loss = 0.0554268, global_step = 491
# INFO:tensorflow:Saving checkpoints for 501 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.30807
# INFO:tensorflow:loss = 0.0369273, step = 501 (43.326 sec)
# INFO:tensorflow:Saving checkpoints for 529 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 559 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 590 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:36:39
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-590
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:36:48
# INFO:tensorflow:Saving dict for global step 590: accuracy = 0.9762, global_step = 590, loss = 0.0757279
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 600): accuracy = 0.9762, loss = 0.0757279, global_step = 590
# INFO:tensorflow:Saving checkpoints for 601 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.28671
# INFO:tensorflow:loss = 0.0156113, step = 601 (43.731 sec)
# INFO:tensorflow:Saving checkpoints for 632 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 662 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 691 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:37:23
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-691
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:37:32
# INFO:tensorflow:Saving dict for global step 691: accuracy = 0.9848, global_step = 691, loss = 0.0497154
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 700): accuracy = 0.9848, loss = 0.0497154, global_step = 691
# INFO:tensorflow:Saving checkpoints for 701 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.28904
# INFO:tensorflow:loss = 0.0453417, step = 701 (43.687 sec)
# INFO:tensorflow:Saving checkpoints for 732 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 762 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 789 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:38:07
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-789
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:38:15
# INFO:tensorflow:Saving dict for global step 789: accuracy = 0.985, global_step = 789, loss = 0.0480822
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 800): accuracy = 0.985, loss = 0.0480822, global_step = 789
# INFO:tensorflow:Saving checkpoints for 801 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.30051
# INFO:tensorflow:loss = 0.00433425, step = 801 (43.468 sec)
# INFO:tensorflow:Saving checkpoints for 832 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 858 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 888 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:38:50
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-888
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:38:58
# INFO:tensorflow:Saving dict for global step 888: accuracy = 0.9862, global_step = 888, loss = 0.0450531
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 900): accuracy = 0.9862, loss = 0.0450531, global_step = 888
# INFO:tensorflow:Saving checkpoints for 901 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.3128
# INFO:tensorflow:loss = 0.00293163, step = 901 (43.237 sec)
# INFO:tensorflow:Saving checkpoints for 903 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 928 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 957 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 988 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:46:31
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-988
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:46:40
# INFO:tensorflow:Saving dict for global step 988: accuracy = 0.9864, global_step = 988, loss = 0.0428551
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 1000): accuracy = 0.9864, loss = 0.0428551, global_step = 988
# INFO:tensorflow:Saving checkpoints for 1001 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.216568
# INFO:tensorflow:loss = 0.0832841, step = 1001 (461.748 sec)
# INFO:tensorflow:Saving checkpoints for 1029 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 1060 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 1092 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:47:15
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-1092
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:47:25
# INFO:tensorflow:Saving dict for global step 1092: accuracy = 0.9882, global_step = 1092, loss = 0.0403689
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 1100): accuracy = 0.9882, loss = 0.0403689, global_step = 1092
# INFO:tensorflow:Saving checkpoints for 1101 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.23981
# INFO:tensorflow:loss = 0.0350798, step = 1101 (44.646 sec)
# INFO:tensorflow:Saving checkpoints for 1132 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 1160 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 1191 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:48:00
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-1191
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:48:09
# INFO:tensorflow:Saving dict for global step 1191: accuracy = 0.9836, global_step = 1191, loss = 0.0572271
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 1200): accuracy = 0.9836, loss = 0.0572271, global_step = 1191
# INFO:tensorflow:Saving checkpoints for 1201 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.27917
# INFO:tensorflow:loss = 0.0120366, step = 1201 (43.876 sec)
# INFO:tensorflow:Saving checkpoints for 1232 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 1262 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 1293 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:48:43
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-1293
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:48:51
# INFO:tensorflow:Saving dict for global step 1293: accuracy = 0.9902, global_step = 1293, loss = 0.037819
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 1300): accuracy = 0.9902, loss = 0.037819, global_step = 1293
# INFO:tensorflow:Saving checkpoints for 1301 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.35966
# INFO:tensorflow:loss = 0.0693228, step = 1301 (42.378 sec)
# INFO:tensorflow:Saving checkpoints for 1331 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 1363 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 1395 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:49:24
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-1395
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:49:33
# INFO:tensorflow:Saving dict for global step 1395: accuracy = 0.9874, global_step = 1395, loss = 0.0410391
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 1400): accuracy = 0.9874, loss = 0.0410391, global_step = 1395
# INFO:tensorflow:Saving checkpoints for 1401 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.4093
# INFO:tensorflow:loss = 0.009033, step = 1401 (41.506 sec)
# INFO:tensorflow:Saving checkpoints for 1433 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 1465 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 1497 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# ...
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:56:57
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-2495
# INFO:tensorflow:Finished evaluation at 2017-08-03-07:57:05
# INFO:tensorflow:Saving dict for global step 2495: accuracy = 0.9914, global_step = 2495, loss = 0.0334698
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 2500): accuracy = 0.9914, loss = 0.0334698, global_step = 2495
# INFO:tensorflow:Saving checkpoints for 2501 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.4198
# INFO:tensorflow:loss = 0.0363952, step = 2501 (41.326 sec)
# INFO:tensorflow:Saving checkpoints for 2532 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 2560 into /tmp/cnn_log/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 2588 into /tmp/cnn_log/model.ckpt.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-7d98672da758>:15: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /Users/li-yunjie/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-08-03-07:57:41
# INFO:tensorflow:Restoring parameters from /tmp/cnn_log/model.ckpt-2588
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-8d9d3b3ba464> in <module>()
#       2     config=learn.RunConfig(save_checkpoints_secs=10))
#       3 classifier.fit(x=train_X, y=train_Y, steps=3200, batch_size=64,
# ----> 4     monitors=[validation_monitor])
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     279             _call_location(), decorator_utils.get_qualified_name(func),
#     280             func.__module__, arg_name, date, instructions)
# --> 281       return func(*args, **kwargs)
#     282     new_func.__doc__ = _add_deprecated_arg_notice_to_docstring(
#     283         func.__doc__, date, instructions)
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in fit(self, x, y, input_fn, steps, batch_size, monitors, max_steps)
#     412     _verify_input_args(x, y, input_fn, None, batch_size)
#     413     if x is not None:
# --> 414       SKCompat(self).fit(x, y, batch_size, steps, max_steps, monitors)
#     415       return self
#     416
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in fit(self, x, y, batch_size, steps, max_steps, monitors)
#    1315                         steps=steps,
#    1316                         max_steps=max_steps,
# -> 1317                         monitors=all_monitors)
#    1318     return self
#    1319
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     279             _call_location(), decorator_utils.get_qualified_name(func),
#     280             func.__module__, arg_name, date, instructions)
# --> 281       return func(*args, **kwargs)
#     282     new_func.__doc__ = _add_deprecated_arg_notice_to_docstring(
#     283         func.__doc__, date, instructions)
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in fit(self, x, y, input_fn, steps, batch_size, monitors, max_steps)
#     428       hooks.append(basic_session_run_hooks.StopAtStepHook(steps, max_steps))
#     429
# --> 430     loss = self._train_model(input_fn=input_fn, hooks=hooks)
#     431     logging.info('Loss for final step: %s.', loss)
#     432     return self
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in _train_model(self, input_fn, hooks)
#     976         loss = None
#     977         while not mon_sess.should_stop():
# --> 978           _, loss = mon_sess.run([model_fn_ops.train_op, model_fn_ops.loss])
#     979       summary_io.SummaryWriterCache.clear()
#     980       return loss
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     482                           feed_dict=feed_dict,
#     483                           options=options,
# --> 484                           run_metadata=run_metadata)
#     485
#     486   def should_stop(self):
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     818                               feed_dict=feed_dict,
#     819                               options=options,
# --> 820                               run_metadata=run_metadata)
#     821       except _PREEMPTION_ERRORS as e:
#     822         logging.info('An error was raised. This may be due to a preemption in '
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     774
#     775   def run(self, *args, **kwargs):
# --> 776     return self._sess.run(*args, **kwargs)
#     777
#     778
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     936               results=outputs[hook] if hook in outputs else None,
#     937               options=options,
# --> 938               run_metadata=run_metadata))
#     939     self._should_stop = self._should_stop or run_context.stop_requested
#     940
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py in after_run(self, run_context, run_values)
#    1153         "monitors"] if "monitors" in run_values.results else {}
#    1154     for m in self._monitors:
# -> 1155       induce_stop = m.step_end(self._last_step, result)
#    1156       if induce_stop:
#    1157         run_context.request_stop()
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py in step_end(self, step, output)
#     354     super(EveryN, self).step_end(step, output)
#     355     if self._every_n_step_begin_called:
# --> 356       return self.every_n_step_end(step, output)
#     357     return False
#     358
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py in every_n_step_end(self, step, outputs)
#     660         x=self.x, y=self.y, input_fn=self.input_fn, batch_size=self.batch_size,
#     661         steps=self.eval_steps, metrics=self.metrics, hooks=self.hooks,
# --> 662         name=self.name)
#     663     stats = []
#     664     for name in validation_outputs:
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     279             _call_location(), decorator_utils.get_qualified_name(func),
#     280             func.__module__, arg_name, date, instructions)
# --> 281       return func(*args, **kwargs)
#     282     new_func.__doc__ = _add_deprecated_arg_notice_to_docstring(
#     283         func.__doc__, date, instructions)
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in evaluate(self, x, y, input_fn, feed_fn, batch_size, steps, metrics, name, checkpoint_path, hooks, log_progress)
#     503     _verify_input_args(x, y, input_fn, feed_fn, batch_size)
#     504     if x is not None:
# --> 505       return SKCompat(self).score(x, y, batch_size, steps, metrics)
#     506
#     507     if metrics is not None and not isinstance(metrics, dict):
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in score(self, x, y, batch_size, steps, metrics)
#    1330         steps=steps,
#    1331         metrics=metrics,
# -> 1332         name='score')
#    1333     if eval_results is not None:
#    1334       eval_results.update({'global_step': global_step})
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in _evaluate_model(self, input_fn, steps, feed_fn, metrics, name, checkpoint_path, hooks, log_progress)
#     826           final_ops=eval_dict,
#     827           hooks=hooks,
# --> 828           config=config_pb2.ConfigProto(allow_soft_placement=True))
#     829       current_global_step = eval_results[global_step_key]
#     830
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/training/evaluation.py in _evaluate_once(checkpoint_path, master, scaffold, eval_ops, feed_dict, final_ops, final_ops_feed_dict, hooks, config)
#     180     if eval_ops is not None:
#     181       while not session.should_stop():
# --> 182         session.run(eval_ops, feed_dict)
#     183
#     184   logging.info('Finished evaluation at ' + time.strftime('%Y-%m-%d-%H:%M:%S',
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     482                           feed_dict=feed_dict,
#     483                           options=options,
# --> 484                           run_metadata=run_metadata)
#     485
#     486   def should_stop(self):
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     818                               feed_dict=feed_dict,
#     819                               options=options,
# --> 820                               run_metadata=run_metadata)
#     821       except _PREEMPTION_ERRORS as e:
#     822         logging.info('An error was raised. This may be due to a preemption in '
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     774
#     775   def run(self, *args, **kwargs):
# --> 776     return self._sess.run(*args, **kwargs)
#     777
#     778
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     928                                   feed_dict=feed_dict,
#     929                                   options=options,
# --> 930                                   run_metadata=run_metadata)
#     931
#     932     for hook in self._hooks:
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     774
#     775   def run(self, *args, **kwargs):
# --> 776     return self._sess.run(*args, **kwargs)
#     777
#     778
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~/anaconda/envs/py3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
